# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Data/train.csv")
df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
# # Aggregate 'min' and 'max' for each column
# df_basics = df.agg(['min', 'max'])

# # Find columns where the 'max' value is equal to 0
# columns_with_max_zero = df_basics.loc['max'] == 0

# # Print the column names where 'max' value is 0
# columns_with_max_zero = columns_with_max_zero[columns_with_max_zero].index.tolist()
# columns_with_max_zero

# %%
#Delete first few columns, excul,leave thsoe 'useful' variables
colnames = df.columns

df_onlyvar = df.drop(columns = colnames[0])

# %%
#Here, since there are 75 columns (drop the first column), divide those variables

part1 = list({74}) + list(range(0,25))
part2 = list({74}) + list(range(26,50))
part3 = list({74}) + list(range(51,73))

df_onlyvar_1 = df_onlyvar[df_onlyvar.columns[part1]]
df_onlyvar_2 = df_onlyvar[df_onlyvar.columns[part2]]
df_onlyvar_3 = df_onlyvar[df_onlyvar.columns[part3]]

# %%
#Make Correlation Heatmap
correlation_p1 = df_onlyvar_1.corr()
correlation_p2 = df_onlyvar_2.corr()
correlation_p3 = df_onlyvar_3.corr()

axis_corr = sns.heatmap(
correlation_p1,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()

axis_corr = sns.heatmap(
correlation_p2,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()

axis_corr = sns.heatmap(
correlation_p3,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()
